# %% [markdown]
# # AI Refactoring Study
#
# ## MSc Dissertation
#
# ### Comparative Evaluation of AI-Generated Software Refactoring Using Large Language Models
#
# Author: Amila Piyasiri
#
# Tools:
# - ChatGPT
# - Gemini
# - Claude
#
# Metrics:
# - Lines of Code (LOC)
# - Cyclomatic Complexity (CC)
# - Maintainability Index (MI)

# %%
from radon.raw import analyze
from radon.complexity import cc_visit
from radon.metrics import mi_visit

# %% [markdown]
# # Experiment 1
#
# Function:
# Cookiecutter_read_user_choice
#
# Model:
# ChatGPT

# %% [markdown]
# # Experiment 1
#
# ## Function Name
# Rich_decimal
#
# ## Large Language Model
# ChatGPT
#
# ## Original Function Location
#
# original_functions/Rich_decimal.py
#
# ## Refactored Function Location
#
# refactored_code/chatgpt/Rich_decimal.py

# %%
from radon.raw import analyze
from radon.complexity import cc_visit
from radon.metrics import mi_visit

file_path = "refactored_code/chatgpt/Rich_decimal.py"

with open(file_path, "r", encoding="utf-8") as f:
    code = f.read()

# Calculate metrics
raw = analyze(code)
loc = raw.loc

complexity = cc_visit(code)
cc = complexity[0].complexity if complexity else 0

mi = mi_visit(code, multi=True)

print("=" * 40)
print("ChatGPT Refactored Metrics")
print("=" * 40)
print(f"Lines of Code (LOC): {loc}")
print(f"Cyclomatic Complexity (CC): {cc}")
print(f"Maintainability Index (MI): {mi:.2f}")
# Out:
# ...
# ChatGPT Refactored Metrics
# ...
# Lines of Code (LOC): 39
# Cyclomatic Complexity (CC): 1
# Maintainability Index (MI): 100.00

# %%
import pandas as pd

results = pd.DataFrame({
    "Function": ["Rich_decimal"],
    "Model": ["ChatGPT"],
    "LOC": [loc],
    "Cyclomatic Complexity": [cc],
    "Maintainability Index": [round(mi, 2)]
})

results
# Out:
#        Function    Model  LOC  Cyclomatic Complexity  Maintainability Index
# 0  Rich_decimal  ChatGPT   39                      1                  100.0

# %%
results.to_csv(
    "results/chatgpt_results.csv",
    index=False
)

print("Results saved successfully!")
# Out:
# Results saved successfully!

# %%
from radon.raw import analyze
from radon.complexity import cc_visit
from radon.metrics import mi_visit


def analyze_python_file(file_path, label):
    with open(file_path, "r", encoding="utf-8") as f:
        code = f.read()

    raw = analyze(code)
    complexity = cc_visit(code)
    mi = mi_visit(code, multi=True)

    print("=" * 50)
    print(label)
    print("=" * 50)
    print(f"Lines of Code (LOC): {raw.loc}")
    print(f"Cyclomatic Complexity: {sum(c.complexity for c in complexity)}")
    print(f"Maintainability Index: {mi:.2f}")
    print()

# %%
analyze_python_file(
    "original_functions/Cookiecutter_read_user_choice.py",
    "Original Function"
)
# Out:
# ...
# Original Function
# ...
# Lines of Code (LOC): 45
# Cyclomatic Complexity: 9
# Maintainability Index: 83.71

# %%
analyze_python_file(
    "refactored_code/chatgpt/Cookiecutter_read_user_choice.py",
    "ChatGPT Refactored Function"
)
# Out:
# ...
# ChatGPT Refactored Function
# ...
# Lines of Code (LOC): 72
# Cyclomatic Complexity: 7
# Maintainability Index: 83.60

# %%
analyze_python_file(
    "refactored_code/gemini/Cookiecutter_read_user_choice.py",
    "Gemini Refactored Function"
)
# Out:
# ...
# Gemini Refactored Function
# ...
# Lines of Code (LOC): 61
# Cyclomatic Complexity: 11
# Maintainability Index: 82.12

# %%
analyze_python_file(
    "refactored_code/claude/Cookiecutter_read_user_choice.py",
    "Claude Refactored Function"
)
# Out:
# ...
# Claude Refactored Function
# ...
# Lines of Code (LOC): 82
# Cyclomatic Complexity: 11
# Maintainability Index: 79.81

# %%
analyze_python_file(
    "original_functions/Flask_wsgi_app.py",
    "Original Flask Function"
)
# Out:
# ...
# Original Flask Function
# ...
# Lines of Code (LOC): 33
# Cyclomatic Complexity: 7
# Maintainability Index: 73.26

# %%
import os

print(os.getcwd())
# Out:
# d:\AI_Refactoring_Study

# %%
import os

print(os.listdir())
# Out:
# ['.git', '.gitignore', '.vscode', 'AI_Refactoring_Study.ipynb', 'graphs', 'LICENSE', 'metrics', 'original_functions', 'README.md', 'refactored_code', 'requirements.txt', 'results', 'scripts', 'venv']

# %%
import os

print(os.listdir("original_functions"))
# Out:
# ['Cookiecutter_read_user_choice.py', 'Flask_wsgi_app.py', 'Pandas_get_filepath_or_buffer.py', 'requests_prepare_url.py', 'Rich_decimal.py', 'sklearn_validate_data.py']

# %%
analyze_python_file(
    "original_functions/Flask_wsgi_app.py",
    "Original Flask Function"
)
# Out:
# ...
# Original Flask Function
# ...
# Lines of Code (LOC): 33
# Cyclomatic Complexity: 7
# Maintainability Index: 73.26

# %%
analyze_python_file(
    "original_functions/Flask_wsgi_app.py",
    "Original Flask Function"
)
# Out:
# ...
# Original Flask Function
# ...
# Lines of Code (LOC): 33
# Cyclomatic Complexity: 7
# Maintainability Index: 73.26

# %%
analyze_python_file(
    "refactored_code/chatgpt/Flask_wsgi_app.py",
    "ChatGPT Flask Function"
)
# Out:
# ...
# ChatGPT Flask Function
# ...
# Lines of Code (LOC): 56
# Cyclomatic Complexity: 7
# Maintainability Index: 86.17

# %%
analyze_python_file(
    "refactored_code/gemini/Flask_wsgi_app.py",
    "Gemini Flask Function"
)
# Out:
# ...
# Gemini Flask Function
# ...
# Lines of Code (LOC): 56
# Cyclomatic Complexity: 7
# Maintainability Index: 85.98

# %%
analyze_python_file(
    "refactored_code/claude/Flask_wsgi_app.py",
    "Claude Flask Function"
)
# Out:
# ...
# Claude Flask Function
# ...
# Lines of Code (LOC): 64
# Cyclomatic Complexity: 7
# Maintainability Index: 82.79

# %%
analyze_python_file(
    "original_functions/Pandas_get_filepath_or_buffer.py",
    "Original Pandas Function"
)
# Out:
# ...
# Original Pandas Function
# ...
# Lines of Code (LOC): 206
# Cyclomatic Complexity: 28
# Maintainability Index: 68.18

# %%
analyze_python_file(
    "refactored_code/chatgpt/Pandas_get_filepath_or_buffer.py",
    "ChatGPT Pandas Function"
)
# Out:
# ...
# ChatGPT Pandas Function
# ...
# Lines of Code (LOC): 195
# Cyclomatic Complexity: 28
# Maintainability Index: 64.66

# %%
analyze_python_file(
    "refactored_code/gemini/Pandas_get_filepath_or_buffer.py",
    "Gemini Pandas Function"
)
# Out:
# ...
# Gemini Pandas Function
# ...
# Lines of Code (LOC): 182
# Cyclomatic Complexity: 26
# Maintainability Index: 67.52

# %%
analyze_python_file(
    "refactored_code/claude/Pandas_get_filepath_or_buffer.py",
    "Claude Pandas Function"
)
# Out:
# ...
# Claude Pandas Function
# ...
# Lines of Code (LOC): 214
# Cyclomatic Complexity: 28
# Maintainability Index: 67.97

# %%
analyze_python_file(
    "refactored_code/gemini/rich_decimal.py",
    "Gemini Rich Decimal"
)
# Out:
# ...
# Gemini Rich Decimal
# ...
# Lines of Code (LOC): 31
# Cyclomatic Complexity: 1
# Maintainability Index: 100.00

# %%
analyze_python_file(
    "refactored_code/claude/rich_decimal.py",
    "Claude Rich Decimal"
)
# Out:
# ...
# Claude Rich Decimal
# ...
# Lines of Code (LOC): 34
# Cyclomatic Complexity: 1
# Maintainability Index: 100.00

# %%
analyze_python_file(
    "D:/AI_Refactoring_Study/original_functions/rich_decimal.py",
    "Original Rich Decimal"
)
# Out:
# ...
# Original Rich Decimal
# ...
# Lines of Code (LOC): 30
# Cyclomatic Complexity: 1
# Maintainability Index: 100.00

# %%
analyze_python_file(
    "original_functions/sklearn_validate_data.py",
    "Original validate_data"
)
# Out:
# ...
# Original validate_data
# ...
# Lines of Code (LOC): 133
# Cyclomatic Complexity: 22
# Maintainability Index: 65.99

# %%
analyze_python_file(
    "refactored_code/chatgpt/sklearn_validate_data.py",
    "ChatGPT validate_data"
)
# Out:
# ...
# ChatGPT validate_data
# ...
# Lines of Code (LOC): 97
# Cyclomatic Complexity: 22
# Maintainability Index: 74.40

# %%
analyze_python_file(
    "refactored_code/gemini/sklearn_validate_data.py",
    "Gemini validate_data"
)
# Out:
# ...
# Gemini validate_data
# ...
# Lines of Code (LOC): 130
# Cyclomatic Complexity: 16
# Maintainability Index: 68.91

# %%
analyze_python_file(
    "refactored_code/claude/sklearn_validate_data.py",
    "Claude validate_data"
)
# Out:
# ...
# Claude validate_data
# ...
# Lines of Code (LOC): 145
# Cyclomatic Complexity: 22
# Maintainability Index: 62.40

# %%
analyze_python_file(
    "original_functions/requests_prepare_url.py",
    "Original prepare_url"
)
# Out:
# ...
# Original prepare_url
# ...
# Lines of Code (LOC): 81
# Cyclomatic Complexity: 18
# Maintainability Index: 73.00

# %%
analyze_python_file(
    "refactored_code/chatgpt/requests_prepare_url.py",
    "ChatGPT prepare_url"
)
# Out:
# ...
# ChatGPT prepare_url
# ...
# Lines of Code (LOC): 70
# Cyclomatic Complexity: 17
# Maintainability Index: 69.84

# %%
analyze_python_file(
    "refactored_code/gemini/requests_prepare_url.py",
    "Gemini prepare_url"
)
# Out:
# ...
# Gemini prepare_url
# ...
# Lines of Code (LOC): 70
# Cyclomatic Complexity: 17
# Maintainability Index: 78.30

# %%
analyze_python_file(
    "refactored_code/claude/requests_prepare_url.py",
    "Claude prepare_url"
)
# Out:
# ...
# Claude prepare_url
# ...
# Lines of Code (LOC): 76
# Cyclomatic Complexity: 18
# Maintainability Index: 75.79
